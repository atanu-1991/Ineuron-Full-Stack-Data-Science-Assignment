# %% [markdown]
# #### 1. In what modes should the PdfFileReader() and PdfFileWriter() File objects will be opened?

# %% [markdown]
# Ans: For PdfFileReader() file objects should be opened in rb -> read binary mode, Whereas for PdfFileWriter() file objects should be opened in wb -> write binary mode.

# %% [markdown]
# #### 2. From a PdfFileReader object, how do you get a Page object for page 5?

# %% [markdown]
# Ans: PdfFileReader class provides a method called getPage(page_no) to get a page object.

# %%
import PyPDF2
a=PyPDF2.PdfFileReader('progit.pdf')
a.getPage(5)
# Out:
# {'/Type': '/Page',
#  '/Trans': {},
#  '/Parent': {'/Type': '/Pages',
#   '/Kids': [IndirectObject(3, 0),
#    IndirectObject(10, 0),
#    IndirectObject(16, 0),
#    IndirectObject(22, 0),
#    IndirectObject(25, 0),
#    IndirectObject(29, 0),
#    IndirectObject(32, 0),
#    IndirectObject(37, 0),
#    IndirectObject(40, 0),
#    IndirectObject(45, 0),
#    IndirectObject(48, 0),
#    IndirectObject(51, 0),
#    IndirectObject(54, 0),
#    IndirectObject(59, 0),
#    IndirectObject(62, 0),
#    IndirectObject(70, 0),
#    IndirectObject(74, 0),
#    IndirectObject(78, 0),
#    IndirectObject(82, 0),
#    IndirectObject(86, 0),
#    IndirectObject(90, 0),
#    IndirectObject(94, 0),
#    IndirectObject(98, 0),
#    IndirectObject(102, 0),
#    IndirectObject(106, 0),
#    IndirectObject(110, 0),
#    IndirectObject(113, 0),
#    IndirectObject(123, 0),
#    IndirectObject(136, 0),
#    IndirectObject(150, 0),
#    IndirectObject(159, 0),
#    IndirectObject(170, 0),
# ...

# %% [markdown]
# #### 3. What PdfFileReader variable stores the number of pages in the PDF document?

# %% [markdown]
# Ans: getNumPages() method of PdfFileReader class stores the no pages in a PDF document

# %%
import PyPDF2
a=PyPDF2.PdfFileReader('progit.pdf')
a.getNumPages()
# Out:
# 574

# %% [markdown]
# #### 4. If a PdfFileReader object’s PDF is encrypted with the password swordfish, what must you do before you can obtain Page objects from it?

# %% [markdown]
# Ans: If a PdfFileReader object’s PDF is encrypted with the password swordfish and you're not aware of it. first read the Pdf using the PdfFileReader Class. PdfFileReader class provides a attribute called isEncrypted to check whether a pdf is encrypted or not. the method returns true if a pdf is encrypted and vice versa.
# if pdf is encrypted use the decrypt() method provided by PdfFileReader class first then try to read the contents/pages of the pdf, else PyPDF2 will raise the following error PyPDF2.utils.PdfReadError: file has not been decrypted

# %%
import PyPDF2
a=PyPDF2.PdfFileReader('abc.pdf')
if a.is_encrypted:
    a.decrypt("swordfish")
for i in range(1,a.getNumPages()):
    print(a.getPage(i).extract_text())

# %% [markdown]
# #### 5. What methods do you use to rotate a page?

# %% [markdown]
# Ans: PyPDF2 Package provides 2 methods to rotate a page:
#
#  1.rotateClockWise() -> For Clockwise rotation
#  2.rotateCounterClockWise() -> For Counter Clockwise rotation
# The PyPDF2 package only allows you to rotate a page in increments of 90 degrees. You will receive an AssertionError otherwise

# %% [markdown]
# #### 6. What is the difference between a Run object and a Paragraph object?

# %% [markdown]
# Ans: The structure of a document is represented by three different data types in python-Docx. At the highest level, a Document object represents the entire document. The Document object contains a list of Paragraph objects for the paragraphs in the document. (A new paragraph begins whenever the user presses ENTER or RETURN while typing in a Word document.) Each of these Paragraph objects contains a list of one or more Run objects.
#
# The text in a Word document is more than just a string. It has font, size, color, and other styling information associated with it. A style in Word is a collection of these attributes. A Run object is a contiguous run of text with the same style. A new Run object is needed whenever the text style changes.

# %% [markdown]
# #### 7. How do you obtain a list of Paragraph objects for a Document object that’s stored in a variable named doc?

# %%
# !pip install python-docx
# Out:
# ...
#   Created wheel for python-docx: filename=python_docx-0.8.11-py3-none-any.whl size=184508 sha256=7d6ea4e1b16035aacfb5db3553dbb0eae5f9edd88dc215aecf8e52e6a659eff4
#   Stored in directory: c:\users\atanu\appdata\local\pip\cache\wheels\83\8b\7c\09ae60c42c7ba4ed2dddaf2b8b9186cb105255856d6ed3dba5
# Successfully built python-docx
# ...

# %%
import docx
doc = docx.Document("Assignment_1.docx")

# %%
# print(doc.paragraphs)
for paragraph in doc.paragraphs:
    print(paragraph.text)
# Out:
# 1. In the below elements which of them are values or an expression? eg:- values can be integer or string and expressions will be mathematical operators.
# *
# 'hello'
# -87.8
# -
# /
#
# 6
#
# Ans:  Values-  ‘hello’, -87.8, 6  Expression- *, - , / , +
#
# 2. What is the difference between string and variable?
# Ans: string is a data type and variable is like a container (a=4),here a is variable which store the value 4.
# 3. Describe three different data types.
# Ans: String,Integer,Float
# 4. What is an expression made up of? What do all expressions do?
# Ans1: expression is made up of operator.
# Ans2: All expression do some operation like addition, multiplication, subtraction etc.
# 5. This assignment statements, like spam = 10. What is the difference between an expression and a statement?
# Ans: spam=10 ,here we can call it is a statement (spam variable is used to store the value 10 using = operator expression)and = operator is expression
# ...

# %% [markdown]
# #### 8. What type of object has bold, underline, italic, strike, and outline variables?####

# %% [markdown]
# Ans: Run object has bold, underline, italic, strike, and outline variables. The text in a Word document is more than just a string. It has font, size, color, and other styling information associated with it.
#
# A style in Word is a collection of these attributes. A Run object is a contiguous run of text with the same style. A new Run object is needed whenever the text style changes.

# %% [markdown]
# #### 9. What is the difference between False, True, and None for the bold variable?

# %%
bold =  True # style set to bold
bold = False # style set to not bold
bold = None # style is not Applicable

# %% [markdown]
# #### 10. How do you create a Document object for a new Word document?

# %%
import docx
doc=docx.Document()
doc.add_heading("iNeuron")
para = doc.add_paragraph()
bold_para = para.add_run('''Full Stack Data Science Bootcamp''')
bold_para.italic = True
doc.save("MyDocument.docx")

# %% [markdown]
# #### 11. How do you add a paragraph with the text 'Hello, there!' to a Document object stored in a variable named doc?####

# %%
import docx
doc = docx.Document()
doc.add_paragraph("Hello, there!")
doc.save("hello.docx")

# %% [markdown]
# #### 12. What integers represent the levels of headings available in Word documents?

# %% [markdown]
# Ans: The levels for a heading in a word document can be specified by using the level attribute inside the add_heading method. There are a total of 10 levels statring for 0 to 9. where level 0 makes a headline with the horizontal line below the text, whereas the heading level 1 is the main heading. Similarly, the other headings are sub-heading with their's font-sizes in decreasing order.
#
# It raises ValueError if any value other than from this range is given as input.

# %%
import docx
doc = docx.Document()

doc.add_heading("Tuitle for the Document",0)

doc.add_heading("Tuitle for the Document",1)
doc.add_heading("Tuitle for the Document",2)
doc.add_heading("Tuitle for the Document",3)
doc.add_heading("Tuitle for the Document",4)
doc.add_heading("Tuitle for the Document",5)
doc.add_heading("Tuitle for the Document",6)
doc.add_heading("Tuitle for the Document",7)
doc.add_heading("Tuitle for the Document",8)
doc.add_heading("Tuitle for the Document",9)

doc.save("level.docx")
